# %% [markdown]
# # Analysing the Broken Windows in DC neigborhoods

# %% [markdown]
# In 1969 Philip Zimbardo decided to tryout a social experiment about disorder. He abandoned two cars, one in a rough neighborhood in New York City and one in a affluent neighborhood in California. Unsurprisingly the car in the bad part of town got stripped and vandalized where the one in California did not. Zimbardo then smashed up the California car and observed that then it was stripped and vandalized. Then a few years later George L. Kelling and James Q. Wilson wrote and article in the Atlantic, they thought these findings could be extrapolated. They were most intrigued by how the experiment observed that once “disorder” begins things unravel quickly. They theorized that if policing stopped chasing the big crimes and focused on small petty crimes like vandalism or broken windows then the police could prevent the big crimes. This theory than informed Rudy Giuliani’s  run as may of New York to clean up the town and it seemed to be working really well. In fact it quickly spread to other metro areas, it has sense been proven that the drop in crime had little to do with this strategy but it still remains popular.
#
# My goal was to use DC data on metro crimes and service requests to see if we can observe what Zimbardo was originally trying to observe. We looked at service requests that would qualify as “broken windows” that would include graffiti, abandoned cars, homeless encampments and illegal dumping.  The goal was to use this service request to predict crime totals in a Bayesian regression with the goal of observing if an increase in the number of broken windows results in a increase in the rate of crime.
#
#
#
# The first hurdle we needed to clear was generating features for our crime and service observation. So for each crime we had we needed to generate a number of broken window events in the area and then calculate the crime totals in the area over the same period. This proved challenging from a computation standpoint. Doing that much great circle distance calculations takes time so function optimization was important. I settled on observing broken windows and crime in a 10 day period before our observation and at a ½ distance from observation. This is because the city estimates service call response time at 10 days and ½ a mile is about 4 blocks in DC. The model we built later can be updated to try different time and distance measures.
#
#
# Exploratory data analysis was next. I needed to understand the spread of crime and service calls across the city to make sure our service calls weren’t only coming from certain areas and that did not seem to be the case. The most useful observation was the jump in broken window events from before 2012 and after. It turns out that was when the city rolled out their 311 app making it easier than ever for citizens to make 311 requests. Having that information in hand it would make sense to model for both and before and after this period and compare our posterior distribution.
#
# Now we were ready to use the pymc library to fit our model. Now pymc is designed for small data sets and our post app roll out set had so many observation that it broke our model. So instead we sampled randomly from the years 2012-2016 18k for each year. Our results were interesting, for our model before the app we actually observed an average of a negative correlation of broken window events to crimes and after the app it had a slight positive correlation. I am hypothesizing that broken window events don’t actually have an impact on crime.
#
# Now challenges and limitations with this approach are many and various. First the service request line can’t be filtered for two people observing the same broken window event. We also need to consider the kind of resident that makes these kind of service requests and that we are not physically observing there broken windows event. Moving forward the hope would be to source additional broken window data and data from more locations.
#
# Broken windows as a foundation of police policy has been discredited with multiple studies since, our findings seem to support that as well. Hopefully I can continue to refine this model and influence the way people view crime in the communities. Broken windows was used as a excuse to harass low income areas and lock up small time offenders. Broken windows grew in popularity due to our need for simple clean solutions to very complex problems.

# %%
# esential items
import pandas as pd
from ipywidgets import FloatProgress
from IPython.display import display
import numpy as np
import time
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# eda libraries and items
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm_notebook
plt.style.use('fivethirtyeight')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext line_profiler



# Modeling stuff
from pymc3 import *
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %% [markdown]
# #### Lets read in our data, opendata.dc.gov has the data we will be using from there metro police and 311 serivce requests.

# %%
crdf = pd.read_csv('../Data/crime_df09_17.csv')
srdf = pd.read_csv('../Data/service_df09_17.csv')
# Out:
# /Users/natalie/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (15,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Data Munging

# %%
def eda(dataframe):
    # This eda Ritika Bhasker's eda function github.com/ritikabhasker/how-to-guides
    # Its the best
    print "Missing Values \n \n", dataframe.isnull().sum(),"\n"
    print "Duplicate Rows \n", dataframe.duplicated().sum(),"\n" 
    print "Dataframe Types \n \n", dataframe.dtypes,"\n"
    print "Dataframe Shape \n", dataframe.shape,"\n"
    print "Dataframe Describe \n \n", dataframe.describe(include='all'),"\n"
    for feature in dataframe:
        print feature
        print dataframe[feature].nunique()

# %%
eda(crdf)
# Out:
# Missing Values
#
# Unnamed: 0                   0
# X                            0
# Y                            0
# CCN                          0
# REPORT_DAT                   0
# SHIFT                        0
# METHOD                       0
# OFFENSE                      0
# BLOCK                        0
# XBLOCK                       0
# YBLOCK                       0
# WARD                        13
# ANC                          0
# DISTRICT                   174
# PSA                        213
# NEIGHBORHOOD_CLUSTER      4055
# BLOCK_GROUP                954
# CENSUS_TRACT               954
# VOTING_PRECINCT             78
# XCOORD                    5190
# YCOORD                    5190
# LATITUDE                     0
# LONGITUDE                    0
# BID                     253655
# START_DATE                  10
# END_DATE                 11321
# OBJECTID                     0
# dtype: int64
#
# Duplicate Rows
# 0
#
# Dataframe Types
#
# Unnamed: 0                int64
# X                       float64
# Y                       float64
# CCN                       int64
# REPORT_DAT               object
# SHIFT                    object
# METHOD                   object
# OFFENSE                  object
# BLOCK                    object
# XBLOCK                  float64
# YBLOCK                  float64
# WARD                    float64
# ANC                      object
# DISTRICT                float64
# PSA                     float64
# NEIGHBORHOOD_CLUSTER     object
# BLOCK_GROUP              object
# CENSUS_TRACT            float64
# VOTING_PRECINCT          object
# XCOORD                  float64
# YCOORD                  float64
# LATITUDE                float64
# LONGITUDE               float64
# BID                      object
# START_DATE               object
# END_DATE                 object
# OBJECTID                  int64
# dtype: object
#
# Dataframe Shape
# (301970, 27)
#
# Dataframe Describe
#
#            Unnamed: 0              X              Y           CCN  \
# count   301970.000000  301970.000000  301970.000000  3.019700e+05
# unique            NaN            NaN            NaN           NaN
# top               NaN            NaN            NaN           NaN
# freq              NaN            NaN            NaN           NaN
# mean     17138.553783     -77.008150      38.906099  1.306870e+07
# std      10202.011483       0.036269       0.031540  2.488225e+06
# min          0.000000     -77.113645      38.813478  1.000600e+05
# 25%       8388.000000     -77.032099      38.891125  1.107933e+07
# 50%      16776.000000     -77.013170      38.906443  1.310986e+07
# 75%      25644.000000     -76.985516      38.925440  1.512199e+07
# max      38448.000000     -76.910014      38.994909  9.943899e+07
#
#                       REPORT_DAT    SHIFT  METHOD      OFFENSE  \
# count                     301970   301970  301970       301970
# unique                    277470        3       3            9
# top     2013-09-16T00:00:00.000Z  EVENING  OTHERS  THEFT/OTHER
# freq                          12   128562  274095       109779
# mean                         NaN      NaN     NaN          NaN
# std                          NaN      NaN     NaN          NaN
# min                          NaN      NaN     NaN          NaN
# 25%                          NaN      NaN     NaN          NaN
# 50%                          NaN      NaN     NaN          NaN
# 75%                          NaN      NaN     NaN          NaN
# max                          NaN      NaN     NaN          NaN
#
#                                       BLOCK         XBLOCK         YBLOCK  \
# count                                301970  301970.000000  301970.000000
# unique                                17439            NaN            NaN
# top     3100 - 3299 BLOCK OF 14TH STREET NW            NaN            NaN
# freq                                   2311            NaN            NaN
# mean                                    NaN  399293.902735  137582.133391
# std                                     NaN    3145.609560    3501.309367
# min                                     NaN  390147.000000  127300.000000
# 25%                                     NaN  397216.000000  135921.000000
# 50%                                     NaN  398858.000000  137620.600000
# 75%                                     NaN  401257.000000  139731.000000
# max                                     NaN  407806.750917  147441.000000
#
#                  WARD     ANC       DISTRICT            PSA  \
# count   301957.000000  301970  301796.000000  301757.000000
# unique            NaN      40            NaN            NaN
# top               NaN      2B            NaN            NaN
# freq              NaN   17082            NaN            NaN
# mean         4.446607     NaN       3.728598     378.064406
# std          2.376267     NaN       1.973844     197.019755
# min          1.000000     NaN       1.000000     101.000000
# 25%          2.000000     NaN       2.000000     206.000000
# 50%          5.000000     NaN       4.000000     401.000000
# 75%          6.000000     NaN       5.000000     507.000000
# max          8.000000     NaN       7.000000     708.000000
#
#        NEIGHBORHOOD_CLUSTER BLOCK_GROUP   CENSUS_TRACT VOTING_PRECINCT  \
# count                297915      301016  301016.000000          301892
# unique                   39         450            NaN             143
# top               Cluster 2    005800 1            NaN    Precinct 129
# freq                  24846        7786            NaN           13351
# mean                    NaN         NaN    6213.126409             NaN
# std                     NaN         NaN    3135.488811             NaN
# min                     NaN         NaN     100.000000             NaN
# 25%                     NaN         NaN    3500.000000             NaN
# 50%                     NaN         NaN    7000.000000             NaN
# 75%                     NaN         NaN    8904.000000             NaN
# max                     NaN         NaN   11100.000000             NaN
#
#                XCOORD         YCOORD       LATITUDE      LONGITUDE       BID  \
# count   296780.000000  296780.000000  301970.000000  301970.000000     48315
# unique            NaN            NaN            NaN            NaN        10
# top               NaN            NaN            NaN            NaN  DOWNTOWN
# freq              NaN            NaN            NaN            NaN     16881
# mean    399301.565974  137577.797190      38.906091     -77.008148       NaN
# std       3145.845770    3502.418055       0.031540       0.036269       NaN
# min     390114.430000  127297.420000      38.813471     -77.113642       NaN
# 25%     397200.360000  135904.195000      38.891117     -77.032097       NaN
# 50%     398871.560000  137620.195000      38.906435     -77.013168       NaN
# 75%     401253.700000  139715.010000      38.925432     -76.985513       NaN
# max     407828.720000  147448.750000      38.994901     -76.910012       NaN
#
#                       START_DATE                  END_DATE      OBJECTID
# count                     301960                    290649  3.019700e+05
# unique                    237776                    245999           NaN
# top     2015-08-23T20:00:00.000Z  2009-01-01T00:00:00.000Z           NaN
# freq                          20                        39           NaN
# mean                         NaN                       NaN  6.269500e+07
# std                          NaN                       NaN  8.279505e+05
# min                          NaN                       NaN  6.102239e+07
# 25%                          NaN                       NaN  6.166688e+07
# 50%                          NaN                       NaN  6.312262e+07
# 75%                          NaN                       NaN  6.324370e+07
# max                          NaN                       NaN  6.337797e+07
#
# Unnamed: 0
# 38449
# X
# 19884
# Y
# 19885
# CCN
# 301885
# REPORT_DAT
# 277470
# SHIFT
# 3
# METHOD
# 3
# OFFENSE
# 9
# BLOCK
# 17439
# XBLOCK
# 15319
# YBLOCK
# 15462
# WARD
# 8
# ANC
# 40
# DISTRICT
# 7
# PSA
# 56
# NEIGHBORHOOD_CLUSTER
# 39
# BLOCK_GROUP
# 450
# CENSUS_TRACT
# 179
# VOTING_PRECINCT
# 143
# XCOORD
# 77048
# YCOORD
# 77164
# LATITUDE
# 19893
# LONGITUDE
# 19894
# BID
# 10
# START_DATE
# 237776
# END_DATE
# 245999
# OBJECTID
# 301970

# %%
eda(srdf)
# Out:
# Missing Values
#
# Unnamed: 0                        0
# X                                 0
# Y                                 0
# OBJECTID                          0
# SERVICECODE                       0
# SERVICECODEDESCRIPTION            0
# SERVICETYPECODEDESCRIPTION       31
# ORGANIZATIONACRONYM               0
# SERVICECALLCOUNT                  0
# ADDDATE                           0
# RESOLUTIONDATE                 4910
# SERVICEDUEDATE                    4
# SERVICEORDERDATE                  0
# INSPECTIONFLAG                    0
# INSPECTIONDATE                35059
# INSPECTORNAME                 53000
# SERVICEORDERSTATUS               31
# STATUS_CODE                   17984
# SERVICEREQUESTID                  0
# PRIORITY                       1048
# STREETADDRESS                  2800
# XCOORD                            0
# YCOORD                            0
# LATITUDE                        547
# LONGITUDE                       547
# CITY                           3298
# STATE                          3298
# ZIPCODE                         556
# MARADDRESSREPOSITORYID         6291
# WARD                            653
# DETAILS                       27116
# dtype: int64
#
# Duplicate Rows
# 0
#
# Dataframe Types
#
# Unnamed: 0                      int64
# X                             float64
# Y                             float64
# OBJECTID                        int64
# SERVICECODE                    object
# SERVICECODEDESCRIPTION         object
# SERVICETYPECODEDESCRIPTION     object
# ORGANIZATIONACRONYM            object
# SERVICECALLCOUNT                int64
# ADDDATE                        object
# RESOLUTIONDATE                 object
# SERVICEDUEDATE                 object
# SERVICEORDERDATE               object
# INSPECTIONFLAG                 object
# INSPECTIONDATE                 object
# INSPECTORNAME                  object
# SERVICEORDERSTATUS             object
# STATUS_CODE                    object
# SERVICEREQUESTID               object
# PRIORITY                       object
# STREETADDRESS                  object
# XCOORD                        float64
# YCOORD                        float64
# LATITUDE                      float64
# LONGITUDE                     float64
# CITY                           object
# STATE                          object
# ZIPCODE                       float64
# MARADDRESSREPOSITORYID        float64
# WARD                           object
# DETAILS                        object
# dtype: object
#
# Dataframe Shape
# (69924, 31)
#
# Dataframe Describe
#
#            Unnamed: 0             X             Y      OBJECTID SERVICECODE  \
# count    69924.000000  69924.000000  69924.000000  6.992400e+04       69924
# unique            NaN           NaN           NaN           NaN           7
# top               NaN           NaN           NaN           NaN       S0181
# freq              NaN           NaN           NaN           NaN       23928
# mean    146727.141010    -77.006667     38.912241  9.965677e+05         NaN
# std      86757.750032      0.034670      0.030142  4.857372e+05         NaN
# min          5.000000    -77.112509     38.813728  5.600000e+01         NaN
# 25%      74449.500000    -77.029965     38.897108  6.203705e+05         NaN
# 50%     148378.500000    -77.012332     38.914338  1.071984e+06         NaN
# 75%     214705.250000    -76.984133     38.931272  1.417946e+06         NaN
# max     322421.000000    -76.909534     38.993573  1.719609e+06         NaN
#
#        SERVICECODEDESCRIPTION                 SERVICETYPECODEDESCRIPTION  \
# count                   69924                                      69893
# unique                      8                                          8
# top           Illegal Dumping  SWMA- Solid Waste Management Admistration
# freq                    23928                                      23193
# mean                      NaN                                        NaN
# std                       NaN                                        NaN
# min                       NaN                                        NaN
# 25%                       NaN                                        NaN
# 50%                       NaN                                        NaN
# 75%                       NaN                                        NaN
# max                       NaN                                        NaN
#
#        ORGANIZATIONACRONYM  SERVICECALLCOUNT                   ADDDATE  \
# count                69924           69924.0                     69924
# unique                   2               NaN                     69788
# top                    DPW               NaN  2009-08-21T10:31:00.000Z
# freq                 69856               NaN                         5
# mean                   NaN               1.0                       NaN
# std                    NaN               0.0                       NaN
# min                    NaN               1.0                       NaN
# 25%                    NaN               1.0                       NaN
# 50%                    NaN               1.0                       NaN
# 75%                    NaN               1.0                       NaN
# max                    NaN               1.0                       NaN
#
#                   RESOLUTIONDATE            SERVICEDUEDATE  \
# count                      65014                     69920
# unique                     62320                     52950
# top     2015-02-27T11:31:20.000Z  2017-02-03T17:00:00.000Z
# freq                          25                       121
# mean                         NaN                       NaN
# std                          NaN                       NaN
# min                          NaN                       NaN
# 25%                          NaN                       NaN
# 50%                          NaN                       NaN
# 75%                          NaN                       NaN
# max                          NaN                       NaN
#
#                 SERVICEORDERDATE INSPECTIONFLAG            INSPECTIONDATE  \
# count                      69924          69924                     34865
# unique                     69788              2                     25436
# top     2009-08-21T10:31:00.000Z              Y  2013-10-02T23:00:45.000Z
# freq                           5          44388                       374
# mean                         NaN            NaN                       NaN
# std                          NaN            NaN                       NaN
# min                          NaN            NaN                       NaN
# 25%                          NaN            NaN                       NaN
# 50%                          NaN            NaN                       NaN
# 75%                          NaN            NaN                       NaN
# max                          NaN            NaN                       NaN
#
#        INSPECTORNAME SERVICEORDERSTATUS STATUS_CODE SERVICEREQUESTID  \
# count          16924              69893       51940            69924
# unique            70                 11           7            69924
# top     Giles, Diane             CLOSED      CLOSED      17-00132902
# freq            2059              62581       48217                1
# mean             NaN                NaN         NaN              NaN
# std              NaN                NaN         NaN              NaN
# min              NaN                NaN         NaN              NaN
# 25%              NaN                NaN         NaN              NaN
# 50%              NaN                NaN         NaN              NaN
# 75%              NaN                NaN         NaN              NaN
# max              NaN                NaN         NaN              NaN
#
#         PRIORITY          STREETADDRESS         XCOORD         YCOORD  \
# count      68876                  67124   69924.000000   69924.000000
# unique         7                  36071            NaN            NaN
# top     STANDARD  181 UHLAND TERRACE NE            NaN            NaN
# freq       67576                     78            NaN            NaN
# mean         NaN                    NaN  399422.559000  138263.895302
# std          NaN                    NaN    3006.905619    3345.988511
# min          NaN                    NaN  390245.490000  127327.730000
# 25%          NaN                    NaN  397402.360000  136583.850000
# 50%          NaN                    NaN  398930.360000  138497.060000
# 75%          NaN                    NaN  401376.272500  140376.840000
# max          NaN                    NaN  407848.390245  147292.583718
#
#             LATITUDE     LONGITUDE        CITY  STATE       ZIPCODE  \
# count   69377.000000  69377.000000       66626  66626  69368.000000
# unique           NaN           NaN           1      1           NaN
# top              NaN           NaN  WASHINGTON     DC           NaN
# freq             NaN           NaN       66626  66626           NaN
# mean       38.912225    -77.006687         NaN    NaN  20013.609200
# std         0.030141      0.034687         NaN    NaN    357.726382
# min        38.813720    -77.112507         NaN    NaN  -2716.000000
# 25%        38.897088    -77.029972         NaN    NaN  20002.000000
# 50%        38.914314    -77.012378         NaN    NaN  20010.000000
# 75%        38.931250    -76.984146         NaN    NaN  20018.000000
# max        38.993565    -76.909531         NaN    NaN  70739.000000
#
#         MARADDRESSREPOSITORYID     WARD  \
# count             63633.000000  69271.0
# unique                     NaN     32.0
# top                        NaN      1.0
# freq                       NaN   7072.0
# mean             201254.002137      NaN
# std              168961.478632      NaN
# min                   0.000000      NaN
# 25%               62443.000000      NaN
# 50%              230947.000000      NaN
# 75%              255611.000000      NaN
# max              913935.000000      NaN
#
#                                               DETAILS
# count                                           42808
# unique                                          29743
# top     Location completed by J.Pickeral and B.Green.
# freq                                              867
# mean                                              NaN
# std                                               NaN
# min                                               NaN
# 25%                                               NaN
# 50%                                               NaN
# 75%                                               NaN
# max                                               NaN
#
# Unnamed: 0
# 63705
# X
# 36117
# Y
# 36145
# OBJECTID
# 69887
# SERVICECODE
# 7
# SERVICECODEDESCRIPTION
# 8
# SERVICETYPECODEDESCRIPTION
# 8
# ORGANIZATIONACRONYM
# 2
# SERVICECALLCOUNT
# 1
# ADDDATE
# 69788
# RESOLUTIONDATE
# 62320
# SERVICEDUEDATE
# 52950
# SERVICEORDERDATE
# 69788
# INSPECTIONFLAG
# 2
# INSPECTIONDATE
# 25436
# INSPECTORNAME
# 70
# SERVICEORDERSTATUS
# 11
# STATUS_CODE
# 7
# SERVICEREQUESTID
# 69924
# PRIORITY
# 7
# STREETADDRESS
# 36071
# XCOORD
# 35099
# YCOORD
# 35419
# LATITUDE
# 41508
# LONGITUDE
# 41253
# CITY
# 1
# STATE
# 1
# ZIPCODE
# 91
# MARADDRESSREPOSITORYID
# 32962
# WARD
# 32
# DETAILS
# 29743

# %% [markdown]
# #### PREP ON SERVICE DF.

# %%
srdf['SERVICECODEDESCRIPTION'].unique()
# we already filtered the the service data by relevant broken windows events,
# but on further reveiw we should drop a few more
# Out:
# array(['Graffiti Removal', 'Graffiti Removal - Paint Voucher Request',
#        'Abandoned Vehicle - On Private Property',
#        'Abandoned Vehicle - On Public Property', 'Illegal Dumping',
#        'Homeless Encampment', 'Abandoned Bicycle',
#        'Graffiti Removal-Paint Voucher Request'], dtype=object)

# %%
srdf = srdf[(srdf['SERVICECODEDESCRIPTION'] == 'Graffiti Removal') | (srdf['SERVICECODEDESCRIPTION'] == 
             'Abandoned Vehicle - On Private Property') | (srdf['SERVICECODEDESCRIPTION'] == 
             'Abandoned Vehicle - On Public Property') | (srdf['SERVICECODEDESCRIPTION'] == 
             'Illegal Dumping') 
            | (srdf['SERVICECODEDESCRIPTION'] == 'Homeless Encampment')
             | (srdf['SERVICECODEDESCRIPTION'] == 'Abandoned Bicycle')]

# %%
srdf['SERVICECODEDESCRIPTION'].value_counts()
# Out:
# Illegal Dumping                            23928
# Abandoned Vehicle - On Public Property     20392
# Graffiti Removal                           16224
# Abandoned Vehicle - On Private Property     7167
# Abandoned Bicycle                           1897
# Homeless Encampment                           68
# Name: SERVICECODEDESCRIPTION, dtype: int64

# %%
srdf = srdf.dropna(subset=['SERVICEDUEDATE'])
# service due date will be the time we chose to use as our measurment so lets drop nulls from that column, not mush lost.

# %%
srdf['Date'] = [x[0:10] for x in srdf['SERVICEDUEDATE']]
# parsing the relevant date information

# %%
srdf['Date'] = pd.to_datetime(srdf['Date'])
# lets make it datetime format

# %%
srdf = srdf.dropna(subset=['LATITUDE','LONGITUDE'])
# also we have to drop nulls from lat long, these will be our measure of space.

# %%
srdf = srdf.drop_duplicates()
# this is a cause for future work we need to devise a way to filter out calls for the same broken window event
# unitl then best we can do is drop any duplicates we have

# %%
srdf.head()
# Out:
#     Unnamed: 0          X          Y  OBJECTID SERVICECODE  \
# 0           18 -77.074151  38.913551    701703       GRAFF
# 1           19 -77.068629  38.905083    701704       GRAFF
# 2           20 -77.081614  38.949695    701705       GRAFF
# 9          103 -77.045176  38.932286    706668       S0003
# 10         410 -77.023227  38.916113    707209       S0000
#
#                      SERVICECODEDESCRIPTION  \
# 0                          Graffiti Removal
# 1                          Graffiti Removal
# 2                          Graffiti Removal
# 9   Abandoned Vehicle - On Private Property
# 10   Abandoned Vehicle - On Public Property
#
#                 SERVICETYPECODEDESCRIPTION ORGANIZATIONACRONYM  \
# 0                                 Graffiti                 DPW
# 1                                 Graffiti                 DPW
# 2                                 Graffiti                 DPW
# 9   Abandoned Vehicle Operations - Private                 DPW
# 10   Abandoned Vehicle Operations - Public                 DPW
#
#     SERVICECALLCOUNT                   ADDDATE            RESOLUTIONDATE  \
# 0                  1  2009-01-16T17:35:18.000Z  2014-09-25T12:59:45.000Z
# 1                  1  2009-01-09T08:47:35.000Z  2014-09-25T12:56:49.000Z
# 2                  1  2009-01-20T15:36:02.000Z  2014-09-25T13:00:53.000Z
# 9                  1  2009-12-31T00:36:11.000Z  2014-10-02T09:48:52.000Z
# 10                 1  2009-12-04T19:23:45.000Z  2014-10-02T09:16:29.000Z
#
#               SERVICEDUEDATE          SERVICEORDERDATE INSPECTIONFLAG  \
# 0   2009-01-30T17:35:18.000Z  2009-01-16T17:35:18.000Z              Y
# 1   2009-01-23T08:47:35.000Z  2009-01-09T08:47:35.000Z              Y
# 2   2009-02-03T15:36:02.000Z  2009-01-20T15:36:02.000Z              Y
# 9   2010-03-15T00:36:11.000Z  2009-12-31T00:36:11.000Z              Y
# 10  2009-12-22T19:23:45.000Z  2009-12-04T19:23:45.000Z              Y
#
#               INSPECTIONDATE    INSPECTORNAME SERVICEORDERSTATUS STATUS_CODE  \
# 0   2014-09-25T12:59:46.000Z  Bowden, Lasharn             CLOSED      CLOSED
# 1   2014-09-25T12:56:50.000Z  Bowden, Lasharn             CLOSED      CLOSED
# 2   2014-09-25T13:00:53.000Z  Bowden, Lasharn             CLOSED      CLOSED
# 9   2013-10-02T23:00:45.000Z              NaN             CLOSED      CLOSED
# 10  2013-10-02T23:00:45.000Z              NaN             CLOSED      CLOSED
#
#    SERVICEREQUESTID  PRIORITY            STREETADDRESS         XCOORD  \
# 0       09-02016407  STANDARD                      NaN  393569.240056
# 1       09-02009851  STANDARD                      NaN  394047.492952
# 2       09-02016987  STANDARD                      NaN  392925.599991
# 9       09-03188751  STANDARD  3225 WALBRIDGE PLACE NW  396083.210000
# 10      09-03161919  STANDARD       1914 8TH STREET NW  397985.830000
#
#            YCOORD   LATITUDE  LONGITUDE        CITY STATE  ZIPCODE  \
# 0   138411.320030  38.913543 -77.074149  WASHINGTON    DC  20007.0
# 1   137470.966333  38.905076 -77.068627  WASHINGTON    DC  20007.0
# 2   142424.200002  38.949688 -77.081612  WASHINGTON    DC  20016.0
# 9   140489.380000  38.932278 -77.045174  WASHINGTON    DC  20010.0
# 10  138693.410000  38.916106 -77.023225  WASHINGTON    DC  20001.0
#
#     MARADDRESSREPOSITORYID WARD  \
# 0                      NaN  2.0
# 1                      NaN  2.0
# 2                      NaN  3.0
# 9                 233384.0  1.0
# 10                239843.0  1.0
#
#                                               DETAILS       Date
# 0   GRAFF ~COMMENTS - PARKING SIGN DEFACED WITH GR... 2009-01-30
# 1   GRAFF ~COMMENTS - TWO TRAFFIC CONTROL BOXES DE... 2009-01-23
# 2   GRAFF ~COMMENTS -  ~LOC - GRAFFITI ON EAST-FAC... 2009-02-03
# 9   Adminstrative Closing\n\n3rd request on these ... 2010-03-15
# 10  Adminstrative Closing\n\nappears to have been ... 2009-12-22

# %%
#srdf.to_csv('service_cleaned.csv', index = False)
# lets save our cleaned data to a csv, we endedup dropping 5% of our data.

# %% [markdown]
# #### LETS DO THIS PREP ON CRIME DF.

# %%
crdf['Date'] = [x[0:10] for x in crdf['REPORT_DAT']]
# The obvious time measurment

# %%
crdf['Date'] = pd.to_datetime(crdf['Date'])
# to datetime format

# %%
srdf = srdf.dropna(subset=['LATITUDE','LONGITUDE'])
# also we have to drop nulls from lat long, these will be our measure of space.

# %%
crdf = crdf.drop_duplicates()

# %%
crdf.head()
# Out:
#    Unnamed: 0          X          Y       CCN                REPORT_DAT  \
# 0           0 -77.031960  38.903136  90096755  2009-07-10T18:30:00.000Z
# 1           1 -76.947212  38.903975  99168068  2009-11-25T23:30:00.000Z
# 2           2 -76.939207  38.895197  99438989  2009-06-23T00:00:00.000Z
# 3           3 -76.999518  38.904689    162302  2009-11-12T18:00:00.000Z
# 4           4 -77.022948  38.917244    174072  2009-12-06T23:30:00.000Z
#
#       SHIFT  METHOD              OFFENSE                                BLOCK  \
# 0   EVENING  OTHERS          THEFT/OTHER  1000 - 1099 BLOCK OF 14TH STREET NW
# 1  MIDNIGHT  OTHERS         THEFT F/AUTO   3500 - 3899 BLOCK OF JAY STREET NE
# 2  MIDNIGHT  OTHERS             HOMICIDE    400 - 499 BLOCK OF 44TH STREET NE
# 3   EVENING  OTHERS  MOTOR VEHICLE THEFT   1100 - 1199 BLOCK OF 5TH STREET NE
# 4  MIDNIGHT  OTHERS         THEFT F/AUTO   2000 - 2099 BLOCK OF 8TH STREET NW
#
#       XBLOCK     YBLOCK  WARD ANC  DISTRICT    PSA NEIGHBORHOOD_CLUSTER  \
# 0  397228.00  137253.00   2.0  2F       1.0  101.0            Cluster 8
# 1  404579.00  137347.00   7.0  7D       6.0  601.0           Cluster 30
# 2  405274.00  136373.00   7.0  7D       6.0  602.0           Cluster 30
# 3  400042.00  137425.00   6.0  6C       1.0  104.0           Cluster 25
# 4  398010.08  138818.94   1.0  1B       3.0  305.0            Cluster 3
#
#   BLOCK_GROUP  CENSUS_TRACT VOTING_PRECINCT     XCOORD     YCOORD   LATITUDE  \
# 0    010100 1       10100.0    Precinct 129  397260.09  137229.87  38.903128
# 1    009602 1        9602.0    Precinct 100  404536.18  137328.87  38.903967
# 2    007803 4        7803.0     Precinct 99  405253.54  136393.83  38.895189
# 3    010600 2       10600.0     Precinct 83  400020.34  137466.29  38.904682
# 4    003500 2        3500.0     Precinct 37  398010.13  138762.60  38.917236
#
#    LONGITUDE       BID                START_DATE                  END_DATE  \
# 0 -77.031958  DOWNTOWN  2009-07-10T11:00:00.000Z  2009-07-10T17:00:00.000Z
# 1 -76.947209       NaN  2009-11-25T08:30:00.000Z  2009-11-25T19:30:00.000Z
# 2 -76.939204       NaN  1999-08-01T04:00:00.000Z  1999-08-02T00:00:00.000Z
# 3 -76.999516       NaN  2009-11-06T12:00:00.000Z  2009-11-12T17:00:00.000Z
# 4 -77.022946       NaN  2009-12-06T21:30:00.000Z  2009-12-06T23:30:00.000Z
#
#    OBJECTID       Date
# 0  61028589 2009-07-10
# 1  61028591 2009-11-25
# 2  61028592 2009-06-23
# 3  61032441 2009-11-12
# 4  61032442 2009-12-06

# %%
# crdf.to_csv('crime_cleaned.csv', index = False)
# save to csv for safe keeping we dropped 2% of our data that were dups

# %% [markdown]
# ## Lets engineer our features that will be our x and y.

# %%
crdfsample = crdf.sample(frac=.01, replace=False, random_state=75)
srdfsample = srdf.sample(frac=.01, replace=False, random_state=75)
# lets make 1% samples to make sure our functions work right, the lat lon math we will do is time intensive.

# %%
# Define a basic Haversine distance formula, I found that this is much faster than using libraries like Geopy.
def haversine(lat1, lon1, lat2, lon2):
    MILES = 3959
    lat1, lon1, lat2, lon2 = map(np.deg2rad, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1 
    dlon = lon2 - lon1 
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a)) 
    total_miles = MILES * c
    return total_miles

# %%
def service_event(crime, service, timelag = 10, distance = .50):

    service_score_list = []

    for crime_index in tqdm_notebook(crime.index):
        count = 0
        crime_date = crime.get_value(crime_index, 'Date')
        crime_lat = crime.get_value(crime_index, 'LATITUDE')
        crime_lon = crime.get_value(crime_index, 'LONGITUDE')

        curr_service = service[(service.Date >= crime_date - pd.Timedelta(timelag,unit='d')) 
                                & (service.Date <= crime_date)]
        
        curr_service['distance'] = haversine(crime_lat,crime_lon,curr_service['LATITUDE'].values, curr_service['LONGITUDE'].values)



               
        for curr_service_index in curr_service.index:
            curr_service_distance = curr_service.get_value(curr_service_index, 'distance')
            if curr_service_distance <= distance:
                count += 1
        service_score_list.append(count)

    return service_score_list

# This is our function. It took me awhile to optimize this so that it would run in less than 5 hrs. This presents scaling 
# problems and trying to generate this with more years of data will take awhile. 
#  For each crime we want to see if there was a broken window event 10 days(that is the cites quote on reponse time)
#  beofre the crime and within 1/2 mileor about 4 blocks in a straight line.

# %%
def crime_totals(crime, timelag = 10, distance = .50):

    crime_score_list = []

    for crime_index in tqdm_notebook(crime.index):
        count = 0
        crime_date = crime.get_value(crime_index, 'Date')
        crime_lat = crime.get_value(crime_index, 'LATITUDE')
        crime_lon = crime.get_value(crime_index, 'LONGITUDE')

        curr_crime = crime[(crime.Date >= crime_date - pd.Timedelta(timelag,unit='d')) 
                                & (crime.Date <= crime_date)]
        
        curr_crime['distance'] = haversine(crime_lat,crime_lon,curr_crime['LATITUDE'].values, curr_crime['LONGITUDE'].values)



               
        for curr_crime_index in curr_crime.index:
            curr_crime_distance = curr_crime.get_value(curr_crime_index, 'distance')
            if curr_crime_distance <= distance:
                count += 1
        crime_score_list.append(count)

    return crime_score_list
# Here we use the same function but now for each crime we want a 
# total of all crimes that happened in the area same as the broken windows.

# %%
# %lprun -f service_event onecentsample_srft = service_event(crdfsample, srdfsample)
# %lprun -f service_event full_srft = service_event(crdf, srdf)
# lpurn gives us a print out that shows how our function is performaing line by line, how cool is that?!
# Out:
# /Users/natalie/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# %lprun -f crime_totals onecentsample_crft = crime_totals(crdfsample)
# %lprun -f crime_totals full_crft = crime_totals(crdf)
# Out:
# /Users/natalie/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
crdfsample['Service_event_full'] = onecentsample_srft
crdfsample['Crime_totals']  = onecentsample_crft
# crdf['Service_event_full'] = full_srft
# crdf['Crime_totals']  = full_crft

# %%
# crdf.to_csv('crime_full.csv', index = False)
# lets also save our csv here safe keeping

# %% [markdown]
# ### Some EDA

# %% [markdown]
# EDA is an imortant part of the data science work flow. For this project alot of our eda took the form of summary stats we see in our eda function out put. I also conducted research on the topic of Broken Windows Theroy,the research behind it and how it was implemnted in cities around the country.

# %%
Crimefull = pd.read_csv('/Users/natalie/Desktop/GA/PROJECT CAPSTONES/crime_full.csv')

# %%
Crimefull.head()
# Out:
#          Date              OFFENSE                                BLOCK WARD  \
# 0  2009-07-10          THEFT/OTHER  1000 - 1099 BLOCK OF 14TH STREET NW  2.0
# 1  2009-11-25         THEFT F/AUTO   3500 - 3899 BLOCK OF JAY STREET NE  7.0
# 2  2009-06-23             HOMICIDE    400 - 499 BLOCK OF 44TH STREET NE  7.0
# 3  2009-11-12  MOTOR VEHICLE THEFT   1100 - 1199 BLOCK OF 5TH STREET NE  6.0
# 4  2009-12-06         THEFT F/AUTO   2000 - 2099 BLOCK OF 8TH STREET NW  1.0
#
#   NEIGHBORHOOD_CLUSTER  CENSUS_TRACT   LATITUDE  LONGITUDE  \
# 0            Cluster 8       10100.0  38.903128 -77.031958
# 1           Cluster 30        9602.0  38.903967 -76.947209
# 2           Cluster 30        7803.0  38.895189 -76.939204
# 3           Cluster 25       10600.0  38.904682 -76.999516
# 4            Cluster 3        3500.0  38.917236 -77.022946
#
#                                     lat_long  Service_event_full  Crime_totals
# 0  (38.903127821200002, -77.031957552400002)                   0            63
# 1  (38.903967050300004, -76.947209466299995)                   0            10
# 2       (38.895189015200003, -76.9392044067)                   1            26
# 3  (38.904681627600006, -76.999515784099998)                   0            24
# 4  (38.917236461999998, -77.022945726099991)                   1            34

# %%
plt.hist(Crimefull['Service_event_full'])
#on our small sample data there isnt alot of variation, but on the full set you will see a large spread.
# And the jump in broken windows events corisponds to the cities roll out of the 311 app.
# Out:
# (array([  2.70827000e+05,   1.96480000e+04,   3.13800000e+03,
#           6.82000000e+02,   2.73000000e+02,   1.02000000e+02,
#           3.60000000e+01,   2.30000000e+01,   9.00000000e+00,
#           3.00000000e+00]),
#  array([   0. ,   20.5,   41. ,   61.5,   82. ,  102.5,  123. ,  143.5,
#          164. ,  184.5,  205. ]),
#  <a list of 10 Patch objects>)

# %%
x=crdfsample['Service_event_full']
y=crdfsample['Crime_totals']
plt.scatter(x,y,alpha=.6)
plt.xkcd
plt.show()

# %%
# plt.hist(Crimefull['WARD'])

# %%
Crimefull['WARD'] = Crimefull['WARD'].astype(str)

# %%
Crimefull['WARD'].dtype
# Out:
# dtype('int64')

# %%
Crimefull = Crimefull.drop(Crimefull[Crimefull.WARD == 'nan'].index)

# %%
Crimefull.shape
# Out:
# (289803, 11)

# %%
Crimefull.groupby(['WARD'])['Service_event_full'].sum().plot(kind= 'bar')

# %%
Crimefull.groupby(['WARD'])['Crime_totals'].sum().plot(kind= 'bar')

# %%
Crimefull.WARD.value_counts().plot(kind= 'bar')

# %%
Crimefull['WARD'].unique()
# Out:
# array(['7.0', '6.0', '1.0', '2.0', '4.0', '5.0', '3.0', '8.0', 'nan'], dtype=object)

# %%
(Crimefull['WARD'] == 'nan')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
# 31        False
# 32        False
# 33        False
# 34        False
# 35        False
# 36        False
# 37        False
# 38        False
# 39        False
# 40        False
# 41        False
# 42        False
# 43        False
# 44        False
# 45        False
# 46        False
# 47        False
# 48        False
# 49        False
# 50        False
# 51        False
# 52        False
# 53        False
# 54        False
# 55        False
# 56        False
# 57        False
# 58        False
# 59        False
# 60        False
# 61        False
# 62        False
# 63        False
# 64        False
# 65        False
# 66        False
# 67        False
# 68        False
# 69        False
# 70        False
# 71        False
# 72        False
# 73        False
# 74        False
# 75        False
# 77        False
# 78        False
# 79        False
# 80        False
# 82        False
# 83        False
# 84        False
# 85        False
# 86        False
# 87        False
# 88        False
# 89        False
# 90        False
# 91        False
# 92        False
# 93        False
# 94        False
# 95        False
# 96        False
# 98        False
# 99        False
# 100       False
# 101       False
# 102       False
# 103       False
# 104       False
# 105       False
# 106       False
# 107       False
# 108       False
# 109       False
# 110       False
# 111       False
# 112       False
# 113       False
# 114       False
# 115       False
# 116       False
# 117       False
# 118       False
# 119       False
# 120       False
# 121       False
# 122       False
# 123       False
# 125       False
# 126       False
# 127       False
# 129       False
# 130       False
# 131       False
# 132       False
# 133       False
# 134       False
# 135       False
# 136       False
# 137       False
# 294578    False
# 294579    False
# 294580    False
# 294581    False
# 294582    False
# 294583    False
# 294584    False
# 294585    False
# 294586    False
# 294587    False
# 294588    False
# 294589    False
# 294590    False
# 294591    False
# 294592    False
# 294593    False
# 294594    False
# 294595    False
# 294596    False
# 294597    False
# 294598    False
# 294599    False
# 294600    False
# 294601    False
# 294602    False
# 294603    False
# 294604    False
# 294605    False
# 294606    False
# 294607    False
# 294608    False
# 294609    False
# 294610    False
# 294611    False
# 294612    False
# 294613    False
# 294614    False
# 294615    False
# 294616    False
# 294617    False
# 294618    False
# 294619    False
# 294620    False
# 294621    False
# 294622    False
# 294623    False
# 294624    False
# 294625    False
# 294626    False
# 294627    False
# 294628    False
# 294629    False
# 294630    False
# 294631    False
# 294632    False
# 294633    False
# 294634    False
# 294635    False
# 294636    False
# 294637    False
# 294638    False
# 294639    False
# 294640    False
# 294641    False
# 294642    False
# 294643    False
# 294644    False
# 294645    False
# 294646    False
# 294647    False
# 294648    False
# 294649    False
# 294650    False
# 294651    False
# 294652    False
# 294653    False
# 294654    False
# 294655    False
# 294656    False
# 294657    False
# 294658    False
# 294659    False
# 294660    False
# 294661    False
# 294662    False
# 294663    False
# 294664    False
# 294665    False
# 294666    False
# 294667    False
# 294668    False
# 294669    False
# 294670    False
# 294671    False
# 294672    False
# 294673    False
# 294674    False
# 294675    False
# 294676    False
# 294677    False
# 294678    False
# 294679    False
# 294680    False
# 294681    False
# 294682    False
# 294683    False
# 294684    False
# 294685    False
# 294686    False
# 294687    False
# 294688    False
# 294689    False
# 294690    False
# 294691    False
# 294692    False
# 294693    False
# 294694    False
# 294695    False
# 294696    False
# 294697    False
# 294698    False
# 294699    False
# 294700    False
# 294701    False
# 294702    False
# 294703    False
# 294704    False
# 294705    False
# 294706    False
# 294707    False
# 294708    False
# 294709    False
# 294710    False
# 294711    False
# 294712    False
# 294713    False
# 294714    False
# 294715    False
# 294716    False
# 294717    False
# 294718    False
# 294719    False
# 294720    False
# 294721    False
# 294722    False
# 294723    False
# 294724    False
# 294725    False
# 294726    False
# 294727    False
# 294728    False
# 294729    False
# 294730    False
# 294731    False
# 294732    False
# 294733    False
# 294734    False
# 294735    False
# 294736    False
# 294737    False
# 294739    False
# 294740    False
# Name: WARD, Length: 289818, dtype: bool

# %%
Crimefull.shape
# Out:
# (294741, 11)

# %%
Crimefull.dropna(inplace=True)

# %%
Crimefull.shape
# Out:
# (289818, 11)

# %%
bins = Crimefull['WARD']

# %%
bins
# Out:
# 0         2.0
# 1         7.0
# 2         7.0
# 3         6.0
# 4         1.0
# 5         1.0
# 6         6.0
# 7         2.0
# 8         4.0
# 9         7.0
# 10        6.0
# 11        1.0
# 12        6.0
# 13        5.0
# 14        7.0
# 15        1.0
# 16        5.0
# 17        6.0
# 18        7.0
# 19        6.0
# 20        6.0
# 21        2.0
# 22        1.0
# 23        6.0
# 24        7.0
# 25        5.0
# 26        6.0
# 27        4.0
# 28        7.0
# 29        1.0
# 31        2.0
# 32        1.0
# 33        1.0
# 294671    2.0
# 294672    1.0
# 294673    1.0
# 294674    1.0
# 294675    2.0
# 294676    6.0
# 294677    1.0
# 294678    2.0
# 294679    1.0
# 294680    4.0
# 294681    2.0
# 294682    1.0
# 294683    5.0
# 294684    2.0
# 294685    2.0
# 294686    5.0
# 294687    1.0
# 294688    7.0
# 294689    6.0
# 294690    1.0
# 294691    4.0
# 294692    7.0
# 294693    8.0
# 294694    1.0
# 294695    7.0
# 294696    1.0
# 294697    2.0
# 294698    5.0
# 294699    1.0
# 294700    6.0
# 294701    3.0
# 294702    6.0
# 294703    6.0
# 294704    1.0
# 294705    8.0
# 294706    1.0
# 294707    7.0
# 294708    5.0
# 294709    7.0
# 294710    1.0
# 294711    7.0
# 294712    3.0
# 294713    6.0
# 294714    7.0
# 294715    4.0
# 294716    7.0
# 294717    8.0
# 294718    1.0
# 294719    6.0
# 294720    6.0
# 294721    1.0
# 294722    8.0
# 294723    6.0
# 294724    3.0
# 294725    7.0
# 294726    5.0
# 294727    5.0
# 294728    7.0
# 294729    6.0
# 294730    1.0
# 294731    4.0
# 294732    5.0
# 294733    6.0
# 294734    1.0
# 294735    6.0
# 294736    7.0
# 294737    4.0
# 294739    5.0
# 294740    4.0
# Name: WARD, Length: 289818, dtype: object

# %%
sns.distplot(Crimefull.groupby(['WARD'])['Service_event_full'].sum(), )

# %%
# plt.hist(Crimefull.groupby(['WARD'])['Service_event_full'].sum(), bins=bins)

# %% [markdown]
# ### Lets model with pymc to get our posterior distribution.

# %%
Crimefull['Date'] = pd.to_datetime(Crimefull['Date'])
Crimefull['year'] = Crimefull['Date'].dt.year
# crdf['year'] = crdf['Date'].dt.year
# lets make a year column to filter our frame by pre app and post app

# %%
crdf_pre11 = Crimefull[Crimefull['year'] <= 2011]
crdf_post11 = Crimefull[Crimefull['year'] >= 2012]
# crdf_pre11 = crdf[crdf['year'] <= 2011]
# crdf_post11 = crdf[crdf['year'] >= 2012]

# %%
crdf_post11['year'].value_counts()
# Out:
# 2014    36832
# 2015    35809
# 2016    35557
# 2013    34551
# 2012    33992
# 2017    20322
# Name: year, dtype: int64

# %%
crdf_post11 = crdf_post11[crdf_post11['year'] < 2017]
# crdf_post11 = crdf_post11[crdf_post11['year'] < 2017]
# lets drop 2017

# %%
# crdf_12 = crdf_post11[crdf_post11['year'] == 2012]
# crdf_13 = crdf_post11[crdf_post11['year'] == 2013]
# crdf_14 = crdf_post11[crdf_post11['year'] == 2014]
# crdf_15 = crdf_post11[crdf_post11['year'] == 2015]
# crdf_16 = crdf_post11[crdf_post11['year'] == 2016]
# # The observations for the full data are to many observations for pymc so we need to random sample 18k per year,

# %%
# crdf_12 = crdf_12.sample(18800)
# crdf_13 = crdf_13.sample(18800)
# crdf_14 = crdf_14.sample(18800)
# crdf_15 = crdf_15.sample(18800)
# crdf_16 = crdf_16.sample(18800)
# #  these samplings are only required on the full data set.

# %%
# crdf_post11 = pd.concat([crdf_12,crdf_13,crdf_14,crdf_15,crdf_16])
# # now we have our sample to model for before the app went live.

# %%
crdf_ward1 = crdf_post11[crdf_post11['WARD'] == '1.0']
crdf_ward2 = crdf_post11[crdf_post11['WARD'] == '2.0']
crdf_ward3 = crdf_post11[crdf_post11['WARD'] == '3.0']
crdf_ward4 = crdf_post11[crdf_post11['WARD'] == '4.0']
crdf_ward5 = crdf_post11[crdf_post11['WARD'] == '5.0']
crdf_ward6 = crdf_post11[crdf_post11['WARD'] == '6.0']
crdf_ward7 = crdf_post11[crdf_post11['WARD'] == '7.0']
crdf_ward8 = crdf_post11[crdf_post11['WARD'] == '8.0']

# %%
crdf_pre11.to_csv('crdf_pre11.csv', index = False)

# %%
crdf_post11.shape
# Out:
# (176741, 12)

# %% [markdown]
# ## WARD 1

# %%
x = crdf_ward1['Service_event_full']

y = crdf_ward1['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 1.2548e+05:   7%|▋         | 13200/200000 [00:06<01:24, 2214.15it/s]
# Convergence archived at 13400
# Interrupted at 13,400 [6%]: Average Loss = 1.3785e+05
# 100%|██████████| 2500/2500 [00:23<00:00, 105.52it/s]

# %%
plt.figure(figsize=(7, 7))
traceplot(trace[100:])
plt.tight_layout();

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x128f6bbd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x128f76950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12921ff10>], dtype=object)

# %% [markdown]
# ## WARD 2

# %%
x = crdf_ward2['Service_event_full']

y = crdf_ward2['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 1.6053e+05:   7%|▋         | 13531/200000 [00:07<01:41, 1833.60it/s]
# Convergence archived at 13700
# Interrupted at 13,700 [6%]: Average Loss = 1.7115e+05
# 100%|██████████| 2500/2500 [00:18<00:00, 133.19it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12fdeb890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12fbe72d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x128db30d0>], dtype=object)

# %% [markdown]
# ## WARD 3

# %%
x = crdf_ward3['Service_event_full']

y = crdf_ward3['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 27,587:   7%|▋         | 13335/200000 [00:03<00:41, 4461.84it/s]
# Convergence archived at 13500
# Interrupted at 13,500 [6%]: Average Loss = 31,113
# 100%|██████████| 2500/2500 [00:08<00:00, 280.82it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x139cb1c10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x139898fd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x139d2b2d0>], dtype=object)

# %% [markdown]
# ## WARD 4

# %%
x = crdf_ward4['Service_event_full']

y = crdf_ward4['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 60,727:   6%|▋         | 12637/200000 [00:04<00:59, 3152.80it/s]
# Convergence archived at 12800
# Interrupted at 12,800 [6%]: Average Loss = 65,907
# 100%|██████████| 2500/2500 [00:12<00:00, 196.37it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1384383d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x136c21a50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x131e8edd0>], dtype=object)

# %% [markdown]
# ## WARD 5

# %%
x = crdf_ward5['Service_event_full']

y = crdf_ward5['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 94,103:   6%|▋         | 12751/200000 [00:07<01:34, 1975.51it/s]
# Convergence archived at 12800
# Interrupted at 12,800 [6%]: Average Loss = 1.0129e+05
# 100%|██████████| 2500/2500 [00:18<00:00, 138.73it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12fbe7c90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1350ba550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1397efd50>], dtype=object)

# %% [markdown]
# ## WARD 6

# %%
x = crdf_ward6['Service_event_full']

y = crdf_ward6['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 1.2485e+05:   7%|▋         | 14645/200000 [00:07<01:55, 1604.23it/s]
# Convergence archived at 14700
# Interrupted at 14,700 [7%]: Average Loss = 1.3263e+05
# 100%|██████████| 2500/2500 [00:16<00:00, 149.75it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x13f891110>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x13bf74550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x139c266d0>], dtype=object)

# %% [markdown]
# ## WARD 7

# %%
x = crdf_ward7['Service_event_full']

y = crdf_ward7['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 81,499:   7%|▋         | 14492/200000 [00:05<01:15, 2444.52it/s]
# Convergence archived at 14700
# Interrupted at 14,700 [7%]: Average Loss = 88,013
# 100%|██████████| 2500/2500 [00:14<00:00, 173.50it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x138456390>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x13ec8c050>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x13e4d8c50>], dtype=object)

# %% [markdown]
# ## WARD 8

# %%
x = crdf_ward8['Service_event_full']

y = crdf_ward8['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# Average Loss = 72,878:   7%|▋         | 14498/200000 [00:05<01:07, 2748.74it/s]
# Convergence archived at 14700
# Interrupted at 14,700 [7%]: Average Loss = 78,332
# 100%|██████████| 2500/2500 [00:13<00:00, 184.91it/s]

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x145d78810>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1459facd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x145a2d410>], dtype=object)

# %% [markdown]
# ### Post app roll out model

# %%
x = crdf_post11['Service_event_full']

y = crdf_post11['Crime_totals']
# x2 = crdf_post11['yearfct'] '"this is for later tinkering I wanted to add year, month, and ward"'

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)
    

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x, 
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# INFO:pymc3:Initializing NUTS using ADVI...
# Average Loss = 1,785.2:  11%|█         | 21430/200000 [00:02<00:22, 8039.90it/s]
# Convergence archived at 22200
# INFO:pymc3.variational.inference:Convergence archived at 22200
# Interrupted at 22,200 [11%]: Average Loss = 3,724.1
# INFO:pymc3.variational.inference:Interrupted at 22,200 [11%]: Average Loss = 3,724.1
# 100%|██████████| 2500/2500 [00:08<00:00, 283.86it/s]

# %%
plt.figure(figsize=(7, 7))
traceplot(trace[100:])
plt.tight_layout();

# %%
summary(trace[100:])
# Out:
# Intercept:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   1.310            0.015            0.000            [1.281, 1.340]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   1.279          1.301          1.311          1.321          1.340
#
#
# x:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.101            0.041            0.001            [0.021, 0.179]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.024          0.073          0.102          0.128          0.182
#
#
# sigma:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.618            0.010            0.000            [0.598, 0.637]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.599          0.611          0.618          0.625          0.638

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1206384d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1213d8c90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1213f7550>], dtype=object)

# %% [markdown]
# ### Lets model or pre app rollout model

# %%
x = crdf_pre11['Service_event_full']

y = crdf_pre11['Crime_totals']

data = dict(x=x, y=y)

# %%
with Model() as model: # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = Uniform('sigma', lower = 0, upper = 50)
    intercept = Normal('Intercept', 0, sd=30)
    x_coeff = Normal('x', 0, sd=1)

    # Define likelihood
    likelihood = Normal('y', mu=intercept + x_coeff * x,
                        sd=sigma, observed=y)

    # Inference!
    trace = sample(2000, njobs=2) # draw 3000 posterior samples using NUTS sampling
# Out:
# Auto-assigning NUTS sampler...
# INFO:pymc3:Auto-assigning NUTS sampler...
# Initializing NUTS using ADVI...
# INFO:pymc3:Initializing NUTS using ADVI...
# Average Loss = 776.23:  14%|█▍        | 28482/200000 [00:03<00:19, 9017.14it/s]
# Convergence archived at 29200
# INFO:pymc3.variational.inference:Convergence archived at 29200
# Interrupted at 29,200 [14%]: Average Loss = 1,618.5
# INFO:pymc3.variational.inference:Interrupted at 29,200 [14%]: Average Loss = 1,618.5
# 100%|██████████| 2500/2500 [00:04<00:00, 532.37it/s]

# %%
plt.figure(figsize=(7, 7))
traceplot(trace[100:])
plt.tight_layout();

# %%
summary(trace[100:])
# Out:
# Intercept:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   1.250            0.017            0.000            [1.215, 1.283]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   1.215          1.239          1.250          1.262          1.284
#
#
# x:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.011            0.996            0.018            [-1.861, 2.061]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -1.993         -0.647         0.019          0.666          1.964
#
#
# sigma:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.538            0.012            0.000            [0.514, 0.562]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.514          0.530          0.538          0.546          0.563

# %%
plot_posterior(trace[100:], color = '#87ceeb')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x125069f90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x12546b5d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1256362d0>], dtype=object)
